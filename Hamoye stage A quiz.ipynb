# %%
import pandas as pd
import numpy as np

# %%
#to import csv dataset 
data= pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Area Code     Area  Item Code         Item  \
# 0           0             0          4  Algeria       2501   Population
# 1           1             1          4  Algeria       2501   Population
# 2           2             2          4  Algeria       2901  Grand Total
# 3           3             3          4  Algeria       2901  Grand Total
# 4           4             4          4  Algeria       2901  Grand Total
#
#    Element Code                                 Element             Unit  \
# 0           511           Total Population - Both sexes     1000 persons
# 1          5301                Domestic supply quantity      1000 tonnes
# 2           664           Food supply (kcal/capita/day)  kcal/capita/day
# 3           674  Protein supply quantity (g/capita/day)     g/capita/day
# 4           684      Fat supply quantity (g/capita/day)     g/capita/day
#
#       Y2014     Y2015     Y2016     Y2017     Y2018
# ...

# %%
#the total sum of Animal Fat produced in 2014
data.groupby('Item')['Y2014'].sum()
# Out:
# Item
# Alcohol, Non-Food        2403.00
# Alcoholic Beverages    102410.11
# Animal Products         11935.65
# Animal fats            209460.54
# Apples and products      9499.23
#                          ...
# Vegetables, Other      155038.96
# Vegetal Products       107145.19
# Wheat and products     232670.13
# Wine                     4497.36
# Yams                   200396.96
# Name: Y2014, Length: 119, dtype: float64

# %%
#the total sum of Animal Fat produced in 2017
data.groupby('Item')['Y2017'].sum()
# Out:
# Item
# Alcohol, Non-Food        2348.00
# Alcoholic Beverages     95581.06
# Animal Products         11547.65
# Animal fats            269617.53
# Apples and products     10198.90
#                          ...
# Vegetables, Other      157752.59
# Vegetal Products       107655.20
# Wheat and products     240047.62
# Wine                     4178.02
# Yams                   229174.59
# Name: Y2017, Length: 119, dtype: float64

# %%
#mean and standard deviation across dataset for the year 2015
data['Y2015'].describe()
# Out:
# count     59395.000000
# mean        135.235966
# std        1603.403984
# min       -3161.000000
# 25%           0.000000
# 50%           0.080000
# 75%           8.460000
# max      181137.000000
# Name: Y2015, dtype: float64

# %%
#total number of missing data in 2016
data['Y2016'].isnull().sum()
# Out:
# 1535

# %%
#total data in 2016
data['Y2016'].count()
# Out:
# 59408

# %%
#percentage of missing data in 2016
#sum of missing data(x), divided by total data(y), multiplied by 100
x = data['Y2016'].isnull().sum()
y = data['Y2016'].count()

(x/y)*100
# Out:
# 2.583827093994075

# %%
#year with the highest correlation with ‘Element Code’
data.corr()
# Out:
#               Unnamed: 0  Unnamed: 0.1  Area Code  Item Code  Element Code  \
# Unnamed: 0      1.000000      1.000000   0.778550   0.007838      0.000212
# Unnamed: 0.1    1.000000      1.000000   0.778550   0.007838      0.000212
# Area Code       0.778550      0.778550   1.000000  -0.005159     -0.000209
# Item Code       0.007838      0.007838  -0.005159   1.000000     -0.024683
# Element Code    0.000212      0.000212  -0.000209  -0.024683      1.000000
# Y2014           0.007846      0.007846   0.006164   0.021722      0.024457
# Y2015           0.006985      0.006985   0.005472   0.020857      0.023889
# Y2016           0.006304      0.006304   0.005247   0.020109      0.023444
# Y2017           0.006693      0.006693   0.005006   0.021494      0.024254
# Y2018           0.006979      0.006979   0.005665   0.021314      0.024279
#
#                  Y2014     Y2015     Y2016     Y2017     Y2018
# Unnamed: 0    0.007846  0.006985  0.006304  0.006693  0.006979
# ...

# %%
#year with the highest sum of Import Quantity
#total sum of Production in 2014

data.groupby('Element').sum()
# Out:
#                                         Unnamed: 0  Unnamed: 0.1  Area Code  \
# Element
# Domestic supply quantity                 160905858     160905858     708993
# Export Quantity                          136913744     136913744     599910
# Fat supply quantity (g/capita/day)       153145800     153145800     675050
# Feed                                      39612522      39612522     176272
# Food                                     150669420     150669420     663295
# Food supply (kcal/capita/day)            153029448     153029448     674057
# Food supply quantity (kg/capita/yr)      149413695     149413695     658446
# Import Quantity                          156184233     156184233     688174
# Losses                                    62224563      62224563     274353
# Other uses (non-food)                     54007001      54007001     235554
# Processing                                60064377      60064377     271940
# ...

# %%
#Which element had the highest sum in 2018
#Which element had the 3rd lowest sum in 2018

data[['Element','Y2018']].groupby('Element').sum().sort_values('Y2018', ascending=True)
# Out:
#                                              Y2018
# Element
# Tourist consumption                          90.00
# Fat supply quantity (g/capita/day)        10258.69
# Protein supply quantity (g/capita/day)    11833.56
# Stock Variation                           20577.91
# Seed                                      25263.14
# Residuals                                 34864.00
# Food supply quantity (kg/capita/yr)       49056.85
# Other uses (non-food)                     91300.97
# Losses                                   163902.00
# Export Quantity                          181594.80
# Feed                                     233489.68
# Import Quantity                          287997.09
# Processing                               308429.00
# Food supply (kcal/capita/day)            455261.00
# Total Population - Both sexes           1140605.00
# Food                                    1303841.28
# Production                              2075072.89
# ...

# %%
# the total Import Quantity in Algeria in 2018
d= data.groupby(['Area','Element'])['Y2018'].sum()
d.head(20)
# Out:
# Area     Element
# Algeria  Domestic supply quantity                  90023.42
#          Export Quantity                             811.54
#          Fat supply quantity (g/capita/day)          309.09
#          Feed                                      10668.00
#          Food                                      63736.33
#          Food supply (kcal/capita/day)             13288.00
#          Food supply quantity (kg/capita/yr)        1509.28
#          Import Quantity                           36238.29
#          Losses                                     7708.00
#          Other uses (non-food)                      3970.08
#          Processing                                 2479.00
#          Production                                60766.67
#          Protein supply quantity (g/capita/day)      367.28
#          Residuals                                   630.00
#          Seed                                        825.00
# ...

# %%
#total number of unique countries in the dataset
len(pd.unique(data['Area']))
# Out:
# 49
